# %%
# %load_ext autoreload
# %autoreload 2
from util.model import ModelLoad
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
load_model = ModelLoad()
model = load_model.model()
load_model.plot_model()

# %%
from util.input import LoadImage
load_input = LoadImage ()
input, mask = load_input.load_image()

# %%
mask.shape
# Out:
# (128, 128, 128)

# %%
from util.print_image import plot_images

plot_images (input [:,:,:,1])

# %%
plot_images (mask)

# %%
from util.getlayer import LayerExtract

inst= LayerExtract (model, input)

# %%
output = inst.save_output()
# Out:
# ...
# 1/1 [==============================] - 1s 1s/step

# %%
output[0].shape
# Out:
# (1, 128, 128, 128, 3)

# %%
plot_images (np.squeeze(output[2][:,:,:,:,1], axis=0))

# %%
plot_images (np.squeeze(output[4][:,:,:,:,1], axis=0))
